# %% [markdown]
# <a href="https://colab.research.google.com/github/ahcamachod/2083-visualizacion-de-datos-composicion-y-relacionamiento/blob/proyecto-final/graficos_de_composicion_y_relacionamiento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **<font color=green>Data Visualization: Gráficos de composición y relacionamiento</font>**
# ---

# %% [markdown]
# # **Clase 1 - Proporción de los datos**

# %% [markdown]
# ## **1.1 Introducción**
#
# ---
#
# En este curso, vamos a construir un portafolio con los análisis de **dos** bases de datos diferentes, explorando cada una y respondiendo a las preguntas planteadas en torno a sus datos. Todas las bases están en formato CSV y se pueden acceder a través de los links indicados.
#
# > **Bases de datos:**
#
# 1.   Tabla con los PIBs (Producto Interno Bruto) de los estados brasileños en el período de 2002 - 2020
#
# 2.   Tabla con la puntuación del Saber 11 (Examen de Estado de la Educación Media en Colombia) de las instituciones educativas a nivel nacional.
#
# En cada clase, vamos a pasar por una base de datos y realización nuestros análisis de acuerdo con las preguntas que se presenten buscando responderlas por medio de la utilización de recursos visuales (gráficos y elementos visuales).

# %% [markdown]
# ### Paleta de colores

# %% [markdown]
# |Azul||||||
# |------|------|------|------|------|------|
# | AZUL1 |AZUL2 |AZUL3 |AZUL4 |AZUL5 |AZUL6 |
# |#174A7E | #4A81BF | #6495ED| #2596be | #94AFC5 | #CDDBF3 |
# |![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/AZUL1.png?raw=true)|![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/AZUL2.png?raw=true)|![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/AZUL3.png?raw=true)|![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/AZUL4.png?raw=true)|![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/AZUL5.png?raw=true)|![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/AZUL6.png?raw=true) |
#
# &nbsp;
#
# |Gris||||||
# |------|------|------|------|------|------|
# | GRIS1 |GRIS2 |GRIS3 |GRIS4 |GRIS5|BLANCO|
# |#231F20 | #414040| #555655 | #A6A6A5| #BFBEBE |#FFFFFF|
# | ![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/CINZA1.png?raw=true)  |![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/CINZA2.png?raw=true) |![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/CINZA3.png?raw=true) |![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/CINZA4.png?raw=true) |![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/CINZA5.png?raw=true)|![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/BRANCO.png?raw=true)|
#
# &nbsp;
#
# |Rojo|||Verde|||
# |------|------|------|------|------|------|
# | ROJO1 |ROJO2 |NARANJA1 | VERDE1 |VERDE2 | VERDE3 |
# |#C3514E | #E6BAB7 | #F79747|#0C8040 | #9ABB59 |#9ECCB3|
# | ![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores//VERMELHO1.png?raw=true) |![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/VERMELHO2.png?raw=true)|![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/LARANJA1.png?raw=true)| ![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/VERDE1.png?raw=true) |![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/VERDE2.png?raw=true)|![adicionar desc](https://github.com/afonsosr2/dataviz-graficos-composicao-relacionamento/blob/638632b27146722cb9589f502a3a444a4eeac717/imagens/paleta_cores/VERDE3.png?raw=true)|

# %%
# Definiendo la paleta de colores
AZUL1, AZUL2, AZUL3, AZUL4, AZUL5, AZUL6 = '#174A7E', '#4A81BF', "#6495ED", '#2596BE', '#94AFC5', '#CDDBF3'
GRIS1, GRIS2, GRIS3, GRIS4, GRIS5, BLANCO = '#231F20', '#414040', '#555655', '#A6A6A5', '#BFBEBE', '#FFFFFF'
ROJO1, ROJO2, NARANJA1 = '#C3514E',	'#E6BAB7',	'#F79747'
VERDE1, VERDE2, VERDE3 = '#0C8040',	'#9ABB59', '#9ECCB3'

# %% [markdown]
# ## **1.2 - Presentando la base de datos**
#
# ---

# %% [markdown]
# ### **Situación-problema 1**
#
# Como científico de datos, has recibido un conjunto de datos para analizar la composición del PIB en relación a los estados de Brasil durante el período de 2002-2020. Los datos describen los valores del PIB y los valores agregados a él anualmente por sectores como agropecuario, industria, servicios y otros.
#
# Aquí, vamos a enfocarnos en investigar la composición de los datos en relación a los estados y regiones y generar algunos comentarios respecto a las preguntas planteadas.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_pib = pd.read_csv("https://gist.githubusercontent.com/ahcamachod/c668d3184f60bd6a56837f2ef6d1adcb/raw/b0050ecd719d8a6581fdda9c43dee0b2877402b8/pib_br_2002_2020.csv")
df_pib.head()
# Out:
#     año estado region          pib  impuesto_liquido           va  \
# 0  2002     RO  Norte   7467629886         839731192   6627898698
# 1  2003     RO  Norte   9425010486        1108434936   8316575548
# 2  2004     RO  Norte  11004641436        1288806654   9715834778
# 3  2005     RO  Norte  12511821181        1476144194  11035676990
# 4  2006     RO  Norte  13054713344        1613809974  11440903374
#
#    va_agropecuaria  va_industria  va_servicios  va_adespss
# 0        715526872    1191090432    2484579193  2236702207
# 1       1278658831    1216605061    3376727040  2444584625
# 2       1288515348    1674933817    3986529419  2765856199
# 3       1342222120    1887932121    4603783904  3201738843
# 4       1238006193    2210692147    4320526746  3671678293

# %%
df_pib.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 513 entries, 0 to 512
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   año               513 non-null    int64
#  1   estado            513 non-null    object
#  2   region            513 non-null    object
#  3   pib               513 non-null    int64
#  4   impuesto_liquido  513 non-null    int64
#  5   va                513 non-null    int64
#  6   va_agropecuaria   513 non-null    int64
#  7   va_industria      513 non-null    int64
#  8   va_servicios      513 non-null    int64
#  9   va_adespss        513 non-null    int64
# dtypes: int64(8), object(2)
# memory usage: 40.2+ KB

# %% [markdown]
# Después de visualizar rápidamente los datos que poseemos, vamos a partir hacia los análisis que podemos hacer con estos datos y qué gráficos de composición vamos a utilizar con el fin de presentar este tipo de información.
#
# ### **Preguntas**
#
# 1. ¿Cómo está dispuesto el PIB en los estados brasileños en el año de 2020? ¿Es posible notar los estados con mayor y menor participación en el PIB nacional?
#
# 2. ¿Hubo un cambio significativo en la distribución del PIB por región comparando los valores de 2002 y 2020?
#
# 3. ¿Cuál es la participación del estado de Minas Gerais en el PIB de todo Brasil en el año de 2020?
#
# 4. ¿Cómo está distribuido el PIB del estado de Bahía en 2020 separado por impuestos líquidos y los valores agregados brutos de los bienes y servicios producidos?
#
# 5. ¿Cuál es la evolución anual del PIB del estado de Río de Janeiro entre los años de 2010 a 2020?
#
# 6. ¿Cómo está distribuido el PIB en los 3 últimos quinquenios (lustro) de los datos (2010, 2015, 2020) en la Región Sur de Brasil divididos por los estados (Paraná, Santa Catarina y Río Grande del Sur)?
#
# 7. ¿Cómo están distribuidos, en porcentaje, los valores agregados de bienes y servicios descritos en la base de datos en relación a cada región en el año de 2020?
#
# 8. En el sector agropecuario, ¿cómo están distribuidos sus valores agregados por región dentro del período de la base de datos (2002 - 2020)?

# %% [markdown]
# ## **1.3 - Problemas en un gráfico de pizza**
#
# ---

# %% [markdown]
# <img src="https://raw.githubusercontent.com/ahcamachod/2083-visualizacion-de-datos-composicion-y-relacionamiento/main/pizza.png" alt="inserir alt" height="343">
#
#
# <font size=2>Fuente: Andrew Abela (Extreme Presentation/Biuwer)</font>

# %% [markdown]
# ### **Pregunta 1 -** ¿Cómo está dispuesto el PIB en los estados brasileños en el año de 2020? ¿Es posible notar los estados con mayor y menor participación en el PIB nacional?

# %% [markdown]
# #### Tratando los datos para generar la visualización

# %%
df_pib_2020 = df_pib.copy()
df_pib_2020 = df_pib_2020.query('año == 2020').set_index('estado').sort_values('pib',ascending=False)[['pib']]
df_pib_2020.head()
# Out:
#                   pib
# estado
# SP      2377638979835
# RJ       753823710636
# MG       682786116407
# PR       487930593779
# RS       470941846057

# %% [markdown]
# #### Generando el gráfico

# %%
fig, ax = plt.subplots(figsize=(6,6))

ax.pie(data=df_pib_2020, x='pib', labels=df_pib_2020.index, autopct='%.1f%%',
       radius=1.1, pctdistance=0.8, textprops={'size':12})

plt.suptitle('Producto Interno Bruto (PIB) por estado (2020)', size=18,color=GRIS1)
plt.title('En porcentaje (%)', fontsize=14, color= GRIS3, pad=15, x=0.1, y=0.98)

ax.text(1.1,0.5,
        'Un $\\bf{gráfico\ de\ pizza}$, logra traer la información de\n'
        'participación en el PIB de forma directa, sin embargo, notamos\n'
        'que el uso de $\\bf{muchas\ porciones}$ dificultan el análisis\n'
        'de datos para los estados con $\\bf{menor}$ aporte en el PIB.\n'
        'Además de ser incómodo visualmente para quien lee.\n\n'
        'Percibimos que los estados de $\\bf{Sao\ Paulo}$, $\\bf{Rio\ de\ Janeiro}$ y $\\bf{Minas\ Gerais}$\n'
        'poseen $\\bf{mayor}$ participación en el PIB nacional, pero, no logramos\n'
        'especificar cuáles son los estados con menor contribución.',
        fontsize=12,
        linespacing=1.45,
        color=GRIS3, transform=ax.transAxes)

plt.show()

# %% [markdown]
# <font color=green size=4> Conclusiones: </font>
#
# ---
#
# Los gráficos de pizza son ideales para mostrar la relación de las partes de un todo. Pero dependiendo de la cantidad de porciones, puede dificultar la visualización de los datos. Sin embargo, podemos aplicarlo cuando presentamos composiciones de datos a través de pequeñas categorías, entre 2 a 5 porciones, o cuando queremos destacar solo 1 valor frente a varias categorías agrupándolas en una sola.
#
# ¿Cómo podrías pasar la participación de los estados con menores valores de PIB? ¿Sería a través del gráfico de pizza o de otra visualización?

# %% [markdown]
# ## **1.4 - Uso apropiado del gráfico de pizza**
#
# ---

# %% [markdown]
# ### **Pregunta 2 -** ¿Hubo un cambio significativo en la distribución del PIB por región comparando los valores de 2002 y 2020?

# %% [markdown]
# #### Tratando los datos para generar la visualización

# %%
df_pib_2002 = df_pib.query('año == 2002')[['region','pib']]
df_pib_2020 = df_pib.query('año == 2020')[['region','pib']]

df_pib_2002 = df_pib_2002.groupby('region').sum().sort_values('pib',ascending=False)
df_pib_2020 = df_pib_2020.groupby('region').sum().sort_values('pib',ascending=False)

display(df_pib_2002, df_pib_2020)
# Out:
#                        pib
# region
# Sudeste       854309793369
# Sur           241564819092
# Noreste       194847656440
# Centro-Oeste  128162640832
# Norte          69902366306
#                         pib
# region
# Sudeste       3952694729239
# Sur           1308147455374
# Noreste       1079331030689
# Centro-Oeste   791250735824
# Norte          478173048893

# %% [markdown]
# #### Generando el gráfico

# %%
fig, axs = plt.subplots(1,2,figsize=(14,6))

colores=[AZUL3,NARANJA1,AZUL5,VERDE1,GRIS5]

plt.suptitle('Producto Interno Bruto (PIB) por región',fontsize=18,
             color=GRIS1, ha='right',x=0.5, y=1.05)

# Gráfico 1
ptc,text, _ = axs[0].pie(data=df_pib_2002, x='pib', labels = df_pib_2002.index,
                         autopct='%.1f%%',pctdistance=0.6,
                         textprops={'size':12,'fontweight':'bold','color':BLANCO},
                         colors=colores)
axs[0].annotate('En 2002',xy=(50,350),size=12, xycoords='axes points',
                bbox=dict(boxstyle='round',fc=BLANCO,ec=GRIS3))

for i,p in enumerate(ptc):
  text[i].set_color(p.get_facecolor())

# Gráfico 2
ptc,text, _ = axs[1].pie(data=df_pib_2020, x='pib', labels = df_pib_2020.index,
                         autopct='%.1f%%',pctdistance=0.6,
                         textprops={'size':12,'fontweight':'bold','color':BLANCO},
                         colors=colores)
axs[1].annotate('En 2020',xy=(50,350),size=12, xycoords='axes points',
                bbox=dict(boxstyle='round',fc=BLANCO,ec=GRIS3))

for i,p in enumerate(ptc):
  text[i].set_color(p.get_facecolor())

# Anotación de una conclusión

axs[0].annotate('La región Sudeste fue la única que\n redujo su participación en el PIB.',
                xy=(180,245),xycoords='axes points', xytext=(280,295),
                textcoords='axes points',
                bbox=dict(boxstyle='round',fc=BLANCO,ec=GRIS3),
                size=10, arrowprops=dict(arrowstyle='->',fc=GRIS1,
                connectionstyle='arc,angleA=-90,angleB=0,armA=30,armB=30,rad=5'))

axs[1].annotate('\n\n',
                xy=(140,245),xycoords='axes points', xytext=(-50,295),
                textcoords='axes points',
                size=10, arrowprops=dict(arrowstyle='->',fc=GRIS1,
                connectionstyle='arc,angleA=-90,angleB=0,armA=30,armB=-30,rad=5'))

plt.show()

# %% [markdown]
# <font color=green size=4> Conclusiones: </font>
#
# ---
#
# Aquí notamos un uso correcto del gráfico de pizza que trajo 5 porciones en total. Hicimos una comparación entre dos períodos por separado, dado que el gráfico de pizza representa composiciones estáticas.
#
# Podemos notar que solo la región Sudeste retrocedió en participación en el PIB en el período que abarca 18 años (2002 - 2020). Es decir, fue posible notar que el PIB fue más distribuido. Podemos percibir este comportamiento sin siquiera necesitar analizar los datos absolutos, solo los relativos.
#
# Como sugerencia, podemos probar añadiendo los valores absolutos del PIB de las regiones o hacer este análisis en una región en específico, como por ejemplo, la región Sur de Brasil (solo 3 estados).

# %% [markdown]
# ## **1.5 - Gráfico de dona**
#
# ---

# %% [markdown]
# ### **Pregunta 3 -** ¿Cuál es la participación del estado de Minas Gerais en el PIB de todo Brasil en el año de 2020?

# %% [markdown]
# #### Tratando los datos para generar la visualización

# %%
df_mg_2020 = df_pib.query('año == 2020')[['estado','pib']]
df_mg_2020.loc[df_mg_2020['estado'] == 'MG', 'estado'] = 'Minas Gerais'
df_mg_2020.loc[df_mg_2020['estado'] != 'Minas Gerais', 'estado'] = 'Otros estados'

df_mg_2020 = df_mg_2020.groupby('estado').sum()
df_mg_2020
# Out:
#                          pib
# estado
# Minas Gerais    682786116407
# Otros estados  6926810883612

# %% [markdown]
# #### Generando el gráfico

# %%
fig,ax = plt.subplots(figsize=(6,6))

colores = [AZUL3,GRIS5]

plt.suptitle('PIB de Minas Gerais con respecto a Brasil en 2020', fontsize=18,
             color=GRIS1, ha='left',x=0,y=0.9)

ptc,text,_ = ax.pie(data=df_mg_2020,x='pib',labels=df_mg_2020.index,
                    autopct='%.1f%%',startangle=0, pctdistance=0.8,
                    wedgeprops=dict(width=0.4),
                    textprops=dict(size=12,fontweight='bold',color=BLANCO),
                    colors=colores)

for i, p in enumerate(ptc):
  text[i].set_color(p.get_facecolor())

plt.show()

# %% [markdown]
# <font color=green size=4> Conclusiones: </font>
#
# ---
#
# El gráfico de dona presenta la mejor forma de utilizar los gráficos de pastel y de dona en una visualización: comparando datos binarios o dicotómicos. Aquí, hicimos la comparación del PIB de Minas Gerais en relación a todo Brasil en el año 2020.
#
# Como sugerencia, podemos analizar otro estado en que tengas interés en comparar con todo Brasil o incluso una región en su totalidad en un año dado.

# %% [markdown]
# # **Aula 2 - Composición de datos estáticos**

# %% [markdown]
# <img src="https://raw.githubusercontent.com/ahcamachod/2083-visualizacion-de-datos-composicion-y-relacionamiento/main/cascada.png" alt="inserir alt" height="343">
#
#
# <font size=2>Fuente: Andrew Abela (Extreme Presentation/Biuwer)</font>

# %% [markdown]
# ## **2.1 - Gráfico de cascada simple**
#
# ---

# %% [markdown]
# ### **Pregunta 4 -** ¿Cómo está distribuido el PIB del estado de Bahía en 2020 separado por impuestos líquidos y los valores agregados brutos de los bienes y servicios producidos?

# %% [markdown]
# #### Tratando los datos para generar la visualización

# %%
bahia = df_pib.query('estado == "BA" & año == 2020')[['pib','impuesto_liquido','va']]
bahia.rename(columns={'pib':'PIB','impuesto_liquido':'Impuestos Líquidos','va':'Valor Agregado Bruto'},inplace=True)
bahia
# Out:
#               PIB  Impuestos Líquidos  Valor Agregado Bruto
# 303  305320812691         37094030606          268226782074

# %%
bahia = bahia.melt(var_name='Indicadores',value_name='Valores')
bahia
# Out:
#             Indicadores       Valores
# 0                   PIB  305320812691
# 1    Impuestos Líquidos   37094030606
# 2  Valor Agregado Bruto  268226782074

# %%
bahia.loc[bahia['Indicadores']=='Impuestos Líquidos','Valores'] = bahia['Valores'] * -1
bahia['Valores_str'] = (bahia['Valores']/1e9).map('R$ {:,.2f} Bi'.format)
bahia['Medidas'] = ['absolute','relative','total']
bahia
# Out:
#             Indicadores       Valores   Valores_str   Medidas
# 0                   PIB  305320812691  R$ 305.32 Bi  absolute
# 1    Impuestos Líquidos  -37094030606  R$ -37.09 Bi  relative
# 2  Valor Agregado Bruto  268226782074  R$ 268.23 Bi     total

# %% [markdown]
# #### Generando el gráfico

# %%
import plotly.graph_objects as go

fig = go.Figure(go.Waterfall(name='',orientation='v',
                             measure=bahia['Medidas'],
                             x=bahia['Indicadores'],y=bahia['Valores'],
                             text=bahia['Valores_str'],
                             textposition='outside',
                             connector_line=dict(color=GRIS3),
                             totals_marker=dict(color=AZUL3),
                             decreasing_marker=dict(color=ROJO1)))

fig.update_layout(width=1000,height=500,font_family='DejaVu Sans',
                  font_size=15, font_color=GRIS2,title_font_color=GRIS1,
                  title_font_size=24,
                  title_text='Distribución del Producto Interno Bruto (PIB) de Bahia em 2020' +
                  '<br><sup size=1 style="color:#555655">Impuestos Líquidos y Valores ' +
                  'Añadidos Brutos de bienes y servicios(en billones de reales)</sup>',
                  title_pad_l=50,plot_bgcolor=BLANCO,yaxis_range=[0,380e9],hovermode='closest')

fig.update_yaxes(showticklabels=False)

fig.update_traces(hovertemplate='<b>%{x}</b> = %{text}')

fig.add_annotation(text='Fuente de los datos: <a href="https://sidra.ibge.gov.br/pesquisa/pib-munic/tabelas">Producto Interno Bruto | IBGE</a>',
                   align="left", xref="paper", yref = "paper", x=1, y=-0.2, showarrow=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="59efd67f-143b-4ecf-8e16-98ed272671a2" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("59efd67f-143b-4ecf-8e16-98ed272671a2")) {                    Plotly.newPlot(                        "59efd67f-143b-4ecf-8e16-98ed272671a2",                        [{"connector":{"line":{"color":"#555655"}},"decreasing":{"marker":{"color":"#C3514E"}},"measure":["absolute","relative","total"],"name":"","orientation":"v","text":["R$ 305.32 Bi","R$ -37.09 Bi","R$ 268.23 Bi"],"textposition":"outside","totals":{"marker":{"color":"#6495ED"}},"x":["PIB","Impuestos L\u00edquidos","Valor Agregado Bruto"],"y":[305320812691,-37094030606,268226782074],"type":"waterfall","hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e = %{text}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"ty ...

# %% [markdown]
# <font color=green size=4> Conclusiones: </font>
#
# ---
#
# Un gráfico de cascada es ampliamente utilizado en datos económicos y financieros debido a su naturaleza de representar de manera simple y directa la acumulación y/o sustracción del total en un período determinado o en diferentes categorías.
#
# Como sugerencia, podemos analizar estos valores desde otro estado de tu preferencia, o incluso separar los valores agregados por tipo de servicio mostrando la agregación de cada uno.
#
# **Observación:** Para ayudar en la comprensión del gráfico, los bienes y servicios finales que componen el PIB se miden al precio al que llegan al consumidor. De esta manera, también se tienen en cuenta los impuestos sobre los productos comercializados.

# %% [markdown]
# ## **2.2 - Añadiendo más incrementos/disminuciones**
#
# ---

# %% [markdown]
# ### **Pregunta 5 -** ¿Cuál es la evolución anual del PIB del estado de Río de Janeiro entre los años de 2010 a 2020?

# %% [markdown]
# #### Tratando los datos para generar la visualización

# %%
anos = [x for x in range(2010,2021)]
rio = df_pib.query('estado=="RJ" & año in @anos')[['año','pib']]
rio = rio.reset_index(drop=True)
rio
# Out:
#      año           pib
# 0   2010  449858101109
# 1   2011  512767904769
# 2   2012  574884973130
# 3   2013  628226069362
# 4   2014  671076844311
# 5   2015  659138951833
# 6   2016  640401206447
# 7   2017  671605668055
# 8   2018  758859046865
# 9   2019  779927917084
# 10  2020  753823710636

# %%
rio['variacion_pib'] = rio['pib'].diff().fillna(rio['pib'].astype('int64'))
rio['Medidas'] = ['absolute'] + ['relative'] * 10
rio
# Out:
#      año           pib  variacion_pib   Medidas
# 0   2010  449858101109   4.498581e+11  absolute
# 1   2011  512767904769   6.290980e+10  relative
# 2   2012  574884973130   6.211707e+10  relative
# 3   2013  628226069362   5.334110e+10  relative
# 4   2014  671076844311   4.285077e+10  relative
# 5   2015  659138951833  -1.193789e+10  relative
# 6   2016  640401206447  -1.873775e+10  relative
# 7   2017  671605668055   3.120446e+10  relative
# 8   2018  758859046865   8.725338e+10  relative
# 9   2019  779927917084   2.106887e+10  relative
# 10  2020  753823710636  -2.610421e+10  relative

# %%
actualizacion = pd.Series({'año':'Total',
                           'pib':rio['pib'].values[-1],
                           'variacion_pib':rio['pib'].values[-1],
                           'Medidas':'total'}).to_frame().T

rio = pd.concat([rio,actualizacion],axis=0, ignore_index=True)
rio = rio.drop(columns=['pib'])

rio['variacion_pib_texto'] = (rio['variacion_pib']/1e9).map('R$ {:,.2f} Bi'.format)
rio.rename(columns={'año':'Año',
                    'variacion_pib':'Variación del PIB',
                    'variacion_pib_texto':'Variación del PIB (texto)'}, inplace=True)

rio
# Out:
#       Año Variación del PIB   Medidas Variación del PIB (texto)
# 0    2010    449858101109.0  absolute              R$ 449.86 Bi
# 1    2011     62909803660.0  relative               R$ 62.91 Bi
# 2    2012     62117068361.0  relative               R$ 62.12 Bi
# 3    2013     53341096232.0  relative               R$ 53.34 Bi
# 4    2014     42850774949.0  relative               R$ 42.85 Bi
# 5    2015    -11937892478.0  relative              R$ -11.94 Bi
# 6    2016    -18737745386.0  relative              R$ -18.74 Bi
# 7    2017     31204461608.0  relative               R$ 31.20 Bi
# 8    2018     87253378810.0  relative               R$ 87.25 Bi
# 9    2019     21068870219.0  relative               R$ 21.07 Bi
# 10   2020    -26104206448.0  relative              R$ -26.10 Bi
# 11  Total      753823710636     total              R$ 753.82 Bi

# %% [markdown]
# #### Generando el gráfico

# %%
fig = go.Figure(go.Waterfall(name='',orientation='v',
                             measure=rio['Medidas'],
                             y=rio['Variación del PIB'],
                             text=rio['Variación del PIB (texto)'],
                             textposition='outside',
                             connector_line=dict(color=GRIS3),
                             totals_marker=dict(color=AZUL3),
                             increasing_marker=dict(color=VERDE1),
                             decreasing_marker=dict(color=ROJO1)))

fig.update_layout(width=1300,height=600,font_family='DejaVu Sans',
                  font_size=15, font_color=GRIS2,title_font_color=GRIS1,
                  title_font_size=24,
                  title_text='Variación del Producto Interno Bruto (PIB) de Río de Janeiro' +
                  '<br><sup size=1 style="color:#555655">De 2010 a 2020 (en billones de reales)</sup>',
                  plot_bgcolor=BLANCO,yaxis_range=[0,850e9])

fig.update_yaxes(showticklabels= False)

fig.update_xaxes(tickmode='array',tickvals=np.arange(0,12),ticktext=rio['Año'])

fig.update_traces(hovertemplate = "<b>%{x}</b> = %{text}")

fig.add_annotation(text="<b>Rio de Janeiro</b> presentó una reducción en el<br>PIB en al menos 3 años durante el período:<br>2015, 2016 y 2020",
                   align="left", axref = 'x', ayref='y', x=5, y=600e9, ax=8, ay=450e9,
                   arrowhead=1, arrowside = "start", showarrow=True, arrowwidth=2, arrowcolor=GRIS3,
                   bordercolor= GRIS3, borderwidth=1, borderpad=4)
fig.add_annotation(text="", axref = 'x', ayref='y', x=6, y=600e9, ax=8, ay=530e9,
                   arrowhead=1, arrowside = "start", showarrow=True, arrowwidth=2, arrowcolor=GRIS3)
fig.add_annotation(text="", axref = 'x', ayref='y', x=10, y=710e9, ax=8.5, ay=530e9,
                   arrowhead=1, arrowside = "start", showarrow=True, arrowwidth=2, arrowcolor=GRIS3)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="af8890cb-ec15-4a60-9a7f-bc442e873e14" class="plotly-graph-div" style="height:600px; width:1300px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("af8890cb-ec15-4a60-9a7f-bc442e873e14")) {                    Plotly.newPlot(                        "af8890cb-ec15-4a60-9a7f-bc442e873e14",                        [{"connector":{"line":{"color":"#555655"}},"decreasing":{"marker":{"color":"#C3514E"}},"increasing":{"marker":{"color":"#0C8040"}},"measure":["absolute","relative","relative","relative","relative","relative","relative","relative","relative","relative","relative","total"],"name":"","orientation":"v","text":["R$ 449.86 Bi","R$ 62.91 Bi","R$ 62.12 Bi","R$ 53.34 Bi","R$ 42.85 Bi","R$ -11.94 Bi","R$ -18.74 Bi","R$ 31.20 Bi","R$ 87.25 Bi","R$ 21.07 Bi","R$ -26.10 Bi","R$ 753.82 Bi"],"textposition":"outside","totals":{"marker":{"color":"#6495ED"}},"y":[449858101109.0,62909803660.0,62117068361.0,53341096232.0,42850774949.0,-11937892478.0,-18737745386.0,31204461608.0,87253378810.0,21068870219.0,-26104206448.0,753823710636],"type":"waterfall","hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e = %{text}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type ...

# %% [markdown]
# <font color=green size=4> Conclusiones: </font>
#
# ---
#
# En este ejemplo, se utilizó el gráfico de cascada para mostrar la evolución del PIB de un estado año tras año, partiendo del valor inicial (año 2010) hasta el final (año 2020, representado por la columna Total). Se pueden observar incrementos y decrementos a lo largo del tiempo, representados por los colores verde y rojo, respectivamente.
#
# Como sugerencia, podemos analizar la evolución del PIB en otra región de tú interés.

# %% [markdown]
# # **Aula 3 - Composición con datos dinámicos**

# %% [markdown]
# <img src="https://raw.githubusercontent.com/ahcamachod/2083-visualizacion-de-datos-composicion-y-relacionamiento/main/cascada.png" alt="inserir alt" height="343">
#
#
# <font size=2>Fuente: Andrew Abela (Extreme Presentation/Biuwer)</font>

# %% [markdown]
# ## **3.1 - Columnas agrupadas x apiladas**
#
# ---

# %% [markdown]
# ### **Pregunta 6 -** ¿Cómo está distribuido el PIB en los 3 últimos quinquenios (lustro) de los datos (2010, 2015, 2020) en la Región Sur de Brasil divididos por los estados (Paraná, Santa Catarina y Río Grande del Sur)?

# %% [markdown]
# #### Tratando los datos para generar la visualización

# %%
anos = [x for x in range(2010,2021,5)]

sur = df_pib.query('region == "Sur" and año in @anos')[['año','estado','pib']]

sur['pib'] = round((sur['pib']/1e9),2)
sur = sur.reset_index(drop=True)

sur
# Out:
#     año estado     pib
# 0  2010     PR  225.21
# 1  2015     PR  376.96
# 2  2020     PR  487.93
# 3  2010     SC  153.73
# 4  2015     SC  249.08
# 5  2020     SC  349.28
# 6  2010     RS  241.25
# 7  2015     RS  381.99
# 8  2020     RS  470.94

# %%
sur_cross = pd.crosstab(index=sur.año,columns=sur.estado,
                        values=sur.pib,aggfunc='sum',
                        normalize='index')
sur_cross = sur_cross.reset_index()
sur_cross
# Out:
# estado   año        PR        RS        SC
# 0       2010  0.363131  0.388994  0.247876
# 1       2015  0.373957  0.378947  0.247096
# 2       2020  0.372992  0.360005  0.267003

# %% [markdown]
# #### Generando el gráfico

# %%
fig,axs = plt.subplots(1,2,figsize=(16,6))
sns.set_theme(style='white')

colores = [AZUL6,VERDE3,ROJO2]

fig.suptitle('Distribución del PIB en  la región Sur de Brasil por quinquenio (2010 - 2020)',
             fontsize=18,color=GRIS1, ha='right', x=0.66, y=1.05)

# Gráfico de columnas agrupadas

sns.barplot(data=sur, x='año',y='pib',hue='estado',hue_order=['PR','RS','SC'], ax= axs[0], palette=colores)

axs[0].set_title('En billones de reales\n',color=GRIS3, loc='left')
axs[0].set_xlabel('')
axs[0].set_ylabel('')
axs[0].xaxis.set_tick_params(labelsize=14, color=GRIS2)
axs[0].yaxis.set_tick_params(labelsize=14, color=GRIS2)
axs[0].set_frame_on(False)

axs[0].legend().remove()
axs[0].yaxis.grid(linestyle='--',linewidth=1)

# Gráfico de columnas 100% apiladas

sur_cross.plot(x='año',kind='bar',stacked=True, color=colores, ax=axs[1])

axs[1].set_title('En porcentajes\n',color=GRIS3, loc='left')
axs[1].set_xlabel('')
axs[1].set_ylabel('')
axs[1].set_yticklabels([])
axs[1].xaxis.set_tick_params(labelsize=14, color=GRIS2, labelrotation=0)
axs[1].set_frame_on(False)

axs[1].legend(bbox_to_anchor=(-0.005,1),title='Estado',title_fontsize=12,
              fontsize=12)

for container in axs[1].containers:
  labels = [f'{valor.get_height()*100:.0f}%' for valor in container]
  axs[1].bar_label(container, label_type='center', labels=labels, size=11,
                   color=GRIS3, fontweight='bold')

plt.show()

# %% [markdown]
# <font color=green size=4> Conclusiones: </font>
#
# ---
#
# En este ejemplo, presentamos las diferencias entre columnas agrupadas y apiladas. La primera refleja los valores absolutos del PIB en cada estado de la Región Sur por quinquenio (lustro), mientras que la segunda representa los valores relativos compilados año a año de la región en su conjunto.

# %% [markdown]
# ## **3.2 - Gráfico de barras apiladas**
#
# ---

# %% [markdown]
# ### **Pregunta 7 -** ¿Cómo están distribuidos, en porcentaje, los valores agregados de bienes y servicios descritos en la base de datos en relación a cada región en el año de 2020?

# %% [markdown]
# #### Tratando los datos para generar la visualización

# %%
df_va_separado = df_pib.query('año == 2020')[['region','va_servicios','va_industria','va_adespss',
                                              'va_agropecuaria']]

df_va_separado = df_va_separado.reset_index(drop=True)
df_va_separado
# Out:
#           region   va_servicios  va_industria    va_adespss  va_agropecuaria
# 0          Norte    19060688172    8285675423   12000339417       6891411669
# 1          Norte     6590543336    1191345379    6031050521        983531817
# 2          Norte    34795836262   35839810630   20210620577       5114449144
# 3          Norte     5278754961    1706511471    6538065265       1000907462
# 4          Norte    56395092425   84173852308   37614037902      19730656823
# 5          Norte     6481918486    2134852286    8255441052        339906135
# 6          Norte    15659235395    4408431382   11408069014       8033173625
# 7        Noreste    39180320014   17379117916   26496332593      11572448702
# 8        Noreste    20907298460    7058009531   16921876934       5699077548
# 9        Noreste    75388196172   25084342421   36177275818       9508982035
# 10       Noreste    29207941814   11811274272   19786450313       3010587934
# 11       Noreste    29024383962   10000792872   20619694846       2823160239
# 12       Noreste    79777759036   34048335567   42281155237       8661859317
# 13       Noreste    22733527234    7391279855   14394347424      12622357004
# 14       Noreste    17160838997    8906254776   12037509338       2583361937
# 15       Noreste   122722534188   59491629932   58005682122      28006935845
# 16       Sudeste   295100108860  166049071678   99949915102      39984391167
# 17       Sudeste    59074177906   31468833016   19093818133       5223319619
# 18       Sudeste   357264648854  157479025721  135691594461       3694432895
# 19       Sudeste  1356311969181  416873007358  197274126779      44391204963
# 20           Sur   201893052968  111144409448   56838129811      56493860969
# 21           Sur   153999389375   78132238752   37750478847      19402797571
# 22           Sur   216008064580   95234088624   62607236661      36152317741
# 23  Centro-Oeste    40463334838   23313710730   20075400418      26045011196
# 24  Centro-Oeste    62253821963   27663774472   23686938663      46004316712
# 25  Centro-Oeste    89797907217   47124851599   33887411346      29022562983
# 26  Centro-Oeste   116547655370   10942472569  111267001381       1623976909

# %%
df_va_separado = df_va_separado.groupby('region').agg('sum')

df_va_separado = df_va_separado.div(df_va_separado.sum(axis=1),axis=0)
df_va_separado = df_va_separado.sort_values(by='va_servicios',axis=0)
df_va_separado
# Out:
#               va_servicios  va_industria  va_adespss  va_agropecuaria
# region
# Norte             0.338521      0.323217    0.239485         0.098777
# Centro-Oeste      0.435471      0.153645    0.266185         0.144699
# Noreste           0.459790      0.191011    0.260121         0.089078
# Sur               0.508060      0.252751    0.139648         0.099541
# Sudeste           0.610871      0.228032    0.133536         0.027561

# %% [markdown]
# #### Generando el gráfico

# %%
def grafico_va():
  fig,ax= plt.subplots(figsize=(10,7))
  colores=[AZUL3,NARANJA1,GRIS5,VERDE3]
  df_va_separado.plot(kind='barh',stacked=True,color=colores,ax=ax)
  plt.suptitle('Valores agregados de bienes y servicios del PIB brasileño en 2020',
               size=18,color=GRIS1,ha='right',x=0.75,y=1.01)
  plt.title('En distribución de los sectores por región (%)\n', fontsize=14,
            color=GRIS3, pad=15, ha='right',x=0.35)
  ax.legend(bbox_to_anchor=(1,1), bbox_transform=ax.transAxes,
            fontsize=10,loc='upper left')
  ax.set_ylabel('')
  ax.set_xticklabels([])
  ax.yaxis.set_tick_params(labelsize=14, color=GRIS2)
  ax.set_frame_on(False)
  for container in ax.containers:
    labels = [f'{valor.get_width()*100:.0f}%' for valor in container]
    ax.bar_label(container, label_type='center', labels=labels, size=10,
                    color=GRIS2, fontweight='bold')

  return ax, colores

ax, colores = grafico_va()

# %% [markdown]
# ## **3.3 - Anotaciones y leyenda de los datos**
#
# ---

# %% [markdown]
# Vamos a trabajar con una función para la escritura de texto utilizando colores diferentes.
#
# > (Adaptada de https://github.com/empathy87/storytelling-with-data)

# %%
# Función para escribir texto usando diferentes colores. No existe una fución
# nativa para hacerlo. (Adaptado de https://github.com/empathy87/storytelling-with-data)
from matplotlib import transforms

def texto_a_color(x, y, texto, colores, esp=20, ax=None, **kw):
    colores = list(reversed(colores))
    t = ax.transData
    canvas = ax.figure.canvas

    for i, linha in enumerate(reversed(texto.split('\n'))):
        frases = linha.split('||')
        for s, cor in zip(frases, colores[i]):
            texto = ax.text(x, y, s, color=cor, transform=t, **kw)
            texto.draw(canvas.get_renderer())
            ex = texto.get_window_extent()
            t = transforms.offset_copy(texto._transform, x=ex.width,
                                       units='dots')

        t = transforms.offset_copy(ax.transData, x=0, y=(i + 1) * esp, units='dots')

# %% [markdown]
# #### Generando el gráfico

# %%
ax,colores = grafico_va()

ax.legend().remove()
texto_a_color(0,4.4,
              '$\\bf{Servicios}$ || | || $\\bf{Industria}$ || | || $\\bf{ADESPSS}$ || | || $\\bf{Agropecuario}$',
              colores=[[colores[0],GRIS3,colores[1],GRIS3,colores[2],GRIS3,colores[3]]],
              ax=ax,fontsize=12)

texto_a_color(1.05,2,
              'El sector de ||$\\bf{servicios}$|| corresponde a la mayor porción\n'        # texto
              'del PIB en todas las regiones. En la región ||$\\bf{Sudeste}$||,\n'
              'este representa ||$\\bf{más\ del\ 60\%}$|| del PIB frente a otros sectores.\n'
              '\n'
              'El sector de ||$\\bf{ADESPSS\ (Administración,\ Defensa,\ Educación,}$\n'
              '$\\bf{Salud\ Pública\ y\ Seguridad\ Social)}$|| es el ||$\\bf{2º\ más\ relevante}$||\n'
              'en el PIB de la región ||$\\bf{Noreste}$||.\n'
              '\n'
              'El sector con menor participación es el ||$\\bf{agropecuario}$||.\n'
              'en la region ||$\\bf{Centro-Oeste}$||, este queda prácticamente empatado\n'
              'con el sector ||$\\bf{industrial}$|| en la región.',
              [[GRIS3, AZUL3, GRIS3],         # fila 1                          # colores
              [GRIS3, GRIS1, GRIS3],        # fila 2
              [GRIS3, GRIS1, GRIS3],        # fila 3
              [GRIS3],                        # fila 4
              [GRIS3, GRIS5],                # fila 5
              [GRIS5, GRIS3, GRIS1],        # fila 6
              [GRIS3, GRIS1, GRIS3],        # fila 7
              [GRIS3],                        # fila 8
              [GRIS3, VERDE3, GRIS3],        # fila 9
              [GRIS3, GRIS1, GRIS3],        # fila 10
              [GRIS3, NARANJA1, GRIS3]       # fila 11
              ],
              esp=22,
              ax=ax,
              fontsize=12)

fig.show()

# %% [markdown]
# <font color=green size=4> Conclusiones: </font>
#
# ---
#
# Las barras apiladas son extremadamente útiles para representar datos en períodos cortos y cuando deseamos comparar diferencias absolutas y relativas o solo relativas (como en el ejemplo anterior).
#
# Como sugerencia, podemos analizar la composición de los datos en relación con los sectores de una región dada, separados por estados.

# %% [markdown]
# # **Aula 4 - Investigando la variación de los datos**

# %% [markdown]
# <img src="https://raw.githubusercontent.com/ahcamachod/2083-visualizacion-de-datos-composicion-y-relacionamiento/main/area.png" alt="inserir alt" height="343">
#
#
# <font size=2>Fuente: Andrew Abela (Extreme Presentation/Biuwer)</font>

# %% [markdown]
# ## **4.1 - Gráfico de área**
#
# ---

# %% [markdown]
# ### **Pregunta 8 -** En el sector agropecuario, ¿cómo están distribuidos sus valores agregados por región dentro del período de la base de datos (2002 - 2020)?

# %% [markdown]
# #### Tratando los datos para generar la visualización

# %%
df_agro = df_pib.copy()
df_agro = df_agro[['region','año','va_agropecuaria']]

df_agro = pd.crosstab(index=df_agro.año, columns=df_agro.region,
                      values=df_agro.va_agropecuaria, aggfunc='sum')
df_agro = (df_agro/1e9).round(2)
df_agro.head()
# Out:
# region  Centro-Oeste  Noreste  Norte  Sudeste    Sur
# año
# 2002           12.98    17.04   6.40    22.57  22.53
# 2003           18.70    20.98   8.14    25.71  32.42
# 2004           20.98    22.44   8.18    28.27  31.05
# 2005           17.04    22.03   8.53    28.99  24.37
# 2006           12.15    23.42   8.91    34.44  26.37

# %% [markdown]
# #### Generando el gráfico

# %%
fig,ax = plt.subplots(figsize=(14,7))
colores=[VERDE3,ROJO2,AZUL3,NARANJA1,GRIS4]
df_agro.plot(kind='area',stacked=True,color=colores,ax=ax,
             xticks=range(2002,2021,2))

ax.set_title('PIB relativo al sector agropecuario en las regiones de Brasil',
             fontsize=18, color=GRIS1, loc='left')
ax.text(0.31,0.98,'De 2002 a 2020 (en billones de reales)',
        transform=ax.transAxes, color=GRIS3, fontsize=12, ha='right', va='center')
ax.set_ylabel('')
ax.xaxis.set_tick_params(labelsize=14, color=GRIS2)
ax.legend().remove()
ax.set_frame_on(False)

reg = list(reversed(df_agro.columns))
color = list(reversed(colores))

for i in range(len(reg)):
  ax.text(0.97,(0.67-i/7),f'{reg[i]}',fontsize=14, color=color[i],
          transform=ax.transAxes)

plt.ylim(0,500)
ax.get_yaxis().set_visible(False)

ax.tick_params(axis='both',which='both', length=0)

agregado_ano = list(df_agro.sum(axis=1).round(2))
for i in range(0, len(df_agro.index),4):
  ax.text(x=df_agro.index[i], y= agregado_ano[i] + 20, s= f'{agregado_ano[i]} Bi',
          color=GRIS3, weight='bold',fontsize=10,ha='center')

ax.text(x=df_agro.index[-1], y= agregado_ano[-1] + 20, s= f'{agregado_ano[-1]} Bi',
          color=GRIS3, weight='bold',fontsize=10,ha='center')

plt.show()

# %% [markdown]
# <font color=green size=4> Conclusiones: </font>
#
# ---
#
# Los gráficos de áreas son extremadamente útiles cuando queremos enfatizar la magnitud de los cambios a lo largo del período. Consisten en una unión de varias líneas apiladas rellenas con el color de cada categoría para representar los datos a lo largo del tiempo. En el ejemplo anterior, utilizamos el gráfico de áreas en el que tanto la diferencia absoluta (valores a lo largo del tiempo) como la relativa (grosor entre ellas) son importantes en nuestro análisis.
#
# Como sugerencia, podemos analizar la composición de los datos en relación con otros sectores.

# %% [markdown]
# ## **4.2 - Gráfico de inclinación**
#
# ---

# %% [markdown]
# #### Tratando los datos para generar la visualización

# %%
df_slope = df_pib.query('año == [2002,2020]')[['region','año','va_agropecuaria']]

df_slope = pd.crosstab(index=df_slope.año, columns=df_slope.region,
                      values=df_slope.va_agropecuaria, aggfunc='sum',
                      normalize='index')
df_slope = (df_slope*100).round(1)
df_slope.head()
# Out:
# region  Centro-Oeste  Noreste  Norte  Sudeste   Sur
# año
# 2002            15.9     20.9    7.9     27.7  27.6
# 2020            23.6     19.4    9.7     21.5  25.8

# %% [markdown]
# #### Generando el gráfico

# %%
def grafico_slope():
  fig,ax1=plt.subplots(figsize=(7,7))
  colores=[VERDE3,ROJO2,AZUL3,NARANJA1,GRIS4]
  ax2=ax1.twinx()
  ax1.set_ylim([0,35])
  ax2.set_ylim([0,35])

  for i in range(5):
    ax1.scatter(x=df_slope.index,y=df_slope.iloc[:,i],
                color=colores[i],s=50)

    ax1.plot(df_slope.index, df_slope.iloc[:,i],
             color=colores[i],lw=3)
    ax1.text(2024,df_slope.iloc[-1,i],
             s=df_slope.columns[i],
             fontsize=15, fontweight='bold',linespacing=1.5, color=colores[i],
             va='center')

  ax1.set_title('PIB relativo al sector agropecuario en las regiones de Brasil',
               fontsize=18, color= GRIS1, loc='left',pad=40)
  ax1.text(0,1.05, 'Comparación entre los años 2002 y 2020 (%)',
           transform=ax1.transAxes, color=GRIS4, fontsize=12, ha='left',va='center')
  return ax1, ax2, colores

ax1,ax2,colores = grafico_slope()

# %% [markdown]
# ## **4.3 - Mejorando el gráfico**
#
# ---

# %%
ax1,ax2,colores = grafico_slope()

ax1.tick_params(left=False)
ax1.spines[['top','right','left']].set_visible(False)
ax2.tick_params(right=False)
ax2.set_frame_on(False)

plt.setp(ax1, xticks=[2002,2020],xticklabels=['2002','2020'],
         yticks=df_slope.iloc[0,:],
         yticklabels=[f'{str(valor)}%' if i !=3 else f'{str(valor)}%\n\n' for i,valor
                      in enumerate(df_slope.iloc[0,:])])

plt.setp(ax2, yticks=df_slope.iloc[1,:],
         yticklabels=[f'{str(valor)}%' for i,valor in enumerate(df_slope.iloc[1,:])])

for ax in (ax1,ax2):
  for i,item in enumerate(ax.get_yticklabels()):
    item.set_fontsize(14)
    item.set_fontweight('bold')
    item.set_color(colores[i])

ax1.xaxis.set_tick_params(labelsize=14, labelcolor=GRIS3)
ax1.spines['bottom'].set_color(GRIS3)

plt.show()

# %% [markdown]
# <font color=green size=4> Conclusiones: </font>
#
# ---
#
# Los gráficos de inclinación son útiles cuando queremos comparar dos períodos de tiempo, mostrando de manera simple y directa los aumentos y disminuciones relativas entre dos puntos de los datos.
#
# Como sugerencia, podemos analizar esta relación desde otros sectores.

# %% [markdown]
# # **Aula 5 - Relacionando los datos**

# %% [markdown]
# ## **5.1 - Presentando la base de datos**
# ---

# %% [markdown]
# ### **Situación-problema 2**
#
# En esta situación problema, has recibido un conjunto de datos para analizar las calificaciones del Saber11, divididas por departamento, de las pruebas realizadas entre 2018 y 2022. Los datos describen el desempeño de los estudiantes en pruebas de Matemáticas, Inglés, Ciencias Naturales, Lectura Crítica y Ciencias Sociales además del puntaje global.
#
# El Saber11 se mide en una escala de 0 a 100, por materia, y es una herramienta importante para seguir el desarrollo de la educación básica en el país, permitiendo la evaluación de la efectividad de las políticas públicas en el área y la identificación de las regiones que necesitan mayor atención.
#
# Aquí, nos enfocaremos en investigar las calificaciones en las diferentes materias (Matemáticas, Inglés, Ciencias Naturales, Lectura Crítica y Ciencias Sociales), haciendo algunos comentarios sobre las preguntas planteadas.

# %%
saber = pd.read_csv('https://caelum-online-public.s3.amazonaws.com/alura-mas/Saber11_2018-2022.csv')
saber.head()
# Out:
#    PERIODO DEPARTAMENTO            MUNICIPIO  \
# 0     2018    ATLANTICO                PIOJÓ
# 1     2018    ANTIOQUIA            ARBOLETES
# 2     2018    ATLANTICO         BARRANQUILLA
# 3     2018    ATLANTICO              SOLEDAD
# 4     2018      BOLIVAR  CARTAGENA DE INDIAS
#
#                                       INSTITUCION  EDAD  \
# 0       INSTITUCION EDUCATIVA NIÑO JESUS DE PRAGA  24.0
# 1                              COLEGIO EL CARMELO  23.0
# 2      CENTRO EDUCATIVO SAN BERNARDO PARA ADULTOS  25.0
# 3  INSTITUCION EDUCATIVA FRANCISCO JOSE DE CALDAS  21.0
# 4               INSTITUCION EDUCATIVA SANTA MARIA  23.0
#
#   FAMI_SITUACIONECONOMICA FAMI_ESTRATOVIVIENDA  PUNT_MATEMATICAS  PUNT_INGLES  \
# 0                    Peor            Estrato 1                30         42.0
# 1                   Igual            Estrato 1                40         41.0
# 2                   Igual            Estrato 2                34         38.0
# 3                   Igual            Estrato 1                54         44.0
# 4                   Igual            Estrato 2                29         29.0
#
#    PUNT_C_NATURALES  PUNT_LECTURA_CRITICA  PUNT_SOCIALES_CIUDADANAS  \
# 0                39                    40                        30
# 1                40                    43                        36
# 2                41                    38                        30
# 3                47                    51                        53
# 4                40                    53                        43
#
#    PUNT_GLOBAL
# 0          177
# 1          199
# 2          180
# 3          253
# 4          202

# %%
saber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2666789 entries, 0 to 2666788
# Data columns (total 13 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   PERIODO                   int64
#  1   DEPARTAMENTO              object
#  2   MUNICIPIO                 object
#  3   INSTITUCION               object
#  4   EDAD                      float64
#  5   FAMI_SITUACIONECONOMICA   object
#  6   FAMI_ESTRATOVIVIENDA      object
#  7   PUNT_MATEMATICAS          int64
#  8   PUNT_INGLES               float64
#  9   PUNT_C_NATURALES          int64
#  10  PUNT_LECTURA_CRITICA      int64
#  11  PUNT_SOCIALES_CIUDADANAS  int64
#  12  PUNT_GLOBAL               int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 264.5+ MB

# %% [markdown]
# Después de visualizar rápidamente los datos que tenemos, vamos a pasar a los análisis que podemos realizar con estos datos y qué gráficos de relación vamos a utilizar para presentar este tipo de información.
#
# ### **Preguntas**
#
# 1. ¿Cuál es la relación entre los puntajes de Matemáticas y de lectura crítica considerando a estudiantes del estrato 4 en el año 2022? ¿Es positiva, negativa o no están correlacionadas?
#
# 2. ¿Cuál es la relación entre los puntajes de inglés y el puntaje global por departamento en la región norte de Colombia (Atlántico, Bolivar, Magdalena, Córdoba y Sucre) considerando a las familias que declararon atravesar una situación económica peor en el año 2020? ¿Podemos trazar algún paralelo entre ellas? Si se sabe que el puntaje para acceder automáticamente a una beca es igual o superior a 360 puntos, y si se considera que el nivel avanzado de inglés es B+ (superior a 80 puntos), ¿puedes mostrar este comportamiento con los 4000 primeros registros de este grupo de estudiantes?

# %% [markdown]
# ## **5.2 - Gráfico de dispersión**
#
# ---

# %% [markdown]
# <img src="https://raw.githubusercontent.com/ahcamachod/2083-visualizacion-de-datos-composicion-y-relacionamiento/main/relacion.png" alt="inserir alt" height="227">
#
#
# <font size=2>Fuente: Andrew Abela (Extreme Presentation/Biuwer)</font>

# %% [markdown]
# ### **Pregunta 1 -** ¿Cuál es la relación entre los puntajes de Matemáticas y de lectura crítica considerando a estudiantes del estrato 4 en el año 2022? ¿Es positiva, negativa o no están correlacionadas?

# %% [markdown]
# #### Visualizando los datos

# %%
saber_mlc= saber.query('FAMI_ESTRATOVIVIENDA == "Estrato 4" & PERIODO == 2022')[['PUNT_MATEMATICAS','PUNT_LECTURA_CRITICA']]
saber_mlc = saber_mlc.reset_index(drop=True)
saber_mlc.head()
# Out:
#    PUNT_MATEMATICAS  PUNT_LECTURA_CRITICA
# 0                21                    36
# 1                28                    25
# 2                21                    32
# 3                23                    36
# 4                21                    24

# %%
saber_mlc.shape
# Out:
# (28092, 2)

# %% [markdown]
# #### Generando el gráfico

# %%
import plotly.express as px

fig = px.scatter(saber_mlc.sample(500),x='PUNT_MATEMATICAS',
                 y='PUNT_LECTURA_CRITICA',trendline='ols',
                 color_discrete_sequence=[AZUL3],
                 trendline_color_override=GRIS3,
                 labels={'PUNT_MATEMATICAS':'Puntaje de Matemáticas',
                         'PUNT_LECTURA_CRITICA':'Puntaje de Lectura Crítica'})

fig.update_layout(width=1000,height=500, yaxis_range=[10,100],
                  xaxis_range=[10,100],
                  margin=dict(t=100),font_size=14, font_color=GRIS2,
                  title_font_color=GRIS1, title_font_size=24,
                  title_text='Relación entre los puntajes de Matemáticas y Lectura Crítica' +
  '<br><sup size=1 style="color:#555655">De las pruebas Saber 11 (Año 2022 - Estrato 4)</sup>',
                  xaxis_title='Matemáticas (0 - 100)', yaxis_title='Lectura Crítica (0 - 100)')

fig.update_traces(hovertemplate="<b>Matemáticas:</b> %{x} <br><b>Lectura Crítica:</b> %{y}",
                  selector=dict(type='scatter',mode='markers'))

fig.add_annotation(text='\n\nFuente de los datos: <a href="https://www.icfes.gov.co/">'
                        'Sistema de evaluación de la calidad educativa (Pruebas Saber11)</a>',
                   align="left", xref="paper", yref = "paper", x=1, y=-0.2, showarrow=False,
                   font_size=10)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a9bd702b-839f-435b-82f0-a8e1de43178d" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a9bd702b-839f-435b-82f0-a8e1de43178d")) {                    Plotly.newPlot(                        "a9bd702b-839f-435b-82f0-a8e1de43178d",                        [{"hovertemplate":"\u003cb\u003eMatem\u00e1ticas:\u003c\u002fb\u003e %{x} \u003cbr\u003e\u003cb\u003eLectura Cr\u00edtica:\u003c\u002fb\u003e %{y}","legendgroup":"","marker":{"color":"#6495ED","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[73,60,71,64,53,57,64,42,60,81,48,51,58,77,53,66,66,36,69,66,71,39,100,49,38,46,62,48,38,48,67,44,61,65,78,51,53,44,57,62,63,72,75,37,52,34,58,78,34,54,44,53,65,40,54,45,52,47,65,29,70,64,72,37,54,56,62,55,74,54,51,56,67,61,42,40,45,28,42,39,69,41,36,64,77,46,58,50,44,39,69,38,35,36,77,24,45,52,58,51,55,71,60,51,68,100,45,64,52,41,64,37,66,57,63,29,73,50,63,63,53,70,53,59,37,46,65,63,61,60,70,34,68,55,35,61,59,46,18,69,68,52,49,57,50,76,45,64,71,55,49,59,40,60,62,59,40,61,75,38,69,40,39,74,58,50,53,71,64,37,59,56,73,42,39,70,31,56,58,100,59,71,65,48,68,43,74,49,63,72,68,48,54,59,41,46,73,64,42,63,27,68,100,70,29,51,42,41,62,46,34,57,24,46,72,58,54,65,30,75,54,34,66,51,50,40,46,32,71,71,30,44,65,36,64,36,61,65,55,36,69,72,57,51,56,23,67,80,59,48,47,58,67,70,60,27,33,63,45,50,62,55,58,50,51,49,59,66,51,53,54,51,46,52,50,63,61,34,50,33,59,66,62,41,47,27,79,52,44,80,45,28,60,64,38,28,61,53,54,75,43,49,64,74,43,61,53,38,73,28,50,76,51,60,79,45,73,39,60,57,53,42,52,42,48,44,67,49,73,26,31,58,35,46,62,21,55,42,48,61,64,37,48,65,65,66,62,39,55,29,31,31,55,75,68,27,64,67,62,30,72,45,34,68,45,75,38,68,64,45,41,67,55,66,69,43,68,46,64,52,49,42,56,37,68,66,40,64,74,36,65,63,63,69,51,54,34,47,56,51,62,69,63,60,66,40,66,32,66,52,27,52,72,44,63,39,63,63,37,34,27,64,57,53,19,37,40,75,43,45,50,35,56,70,36,70,27,63,34,51,45,62,50,66,39,43,53,68,41,69,57,49,40,55,68,50,32,78,61,52,24,71,70,60,60,70,50,53,78,64,47,68,55,36,71,53,74,68,68,100,58,66,56,48,71,73,52,76,35,63,49,39,36,43,62,70,52,36,53,57],"xaxis":"x","y":[71,65,62,69,52,58,72,42,60,79,54,41,61,70,65,69,69,47,65,61,66,42,76,53,38,50,69,53,43,51,65,47,70,58,77,61,67,44,51,70,65,57,75,48,51,50,60,69,36,49,48,60,75,36,55,56,56,53,62,40,74,59,69,32,65,61,79,52,76,68,55,53,61,66,48,50,55,52,43,35,69,46,32,52,76,51,64,50,39,28,71,49,45,37,68,29,46,53,53,41,58,68,67,48,76,80,31,63,63,29,63,46,76,63,61,39,71,49,62,68,56,75,50,59,34,46,58,60,59,65,65,51,68,55,29,61,57,38,32,60,58,62,57,45,43,100,53,58,64,54,49,70,40,57,63,58,39,64,73,37,77,37,42,73,57,60,53,72,70,38,53,58,72,62,32,69,34,54,63,76,65,66,77,59,65,44,76,50,64,60,65,50,45,60,47,52,69,64,56,41,35,66,74,67,29,57,47,24,58,57,47,57,46,51,72,57,58,63,27,75,55,39,64,54,57,40,47,37,100,73,32,45,70,60,57,39,55,73,62,48,65,66,66,64,55,66,100,76,60,65,43,66,62,65,61,47,36,69,53,58,59,50,64,62,50,56,57,67,56,55,68,60,46,41,41,65,59,38,56,41,54,59,68,54,62,34,67,57,40,74,52,34,67,71,38,35,62,50,52,81,46,34,67,77,48,59,56,29,69,36,55,75,54,63,68,41,79,37,66,42,55,35,62,51,56,58,63,62,70,55,30,58,34,53,64,32,53,44,50,56,64,44,46,53,66,71,62,44,54,37,39,41,50,72,74,41,64,68,63,43,69,47,41,64,41,60,50,69,60,51,48,67,55,69,67,46,58,57,67,51,42,39,59,31,59,63,47,56,67,37,69,66,67,68,51,60,39,39,59,50,58,67,78,58,60,46,73,58,65,50,33,68,69,64,65,49,69,62,44,47,40,61,65,49,39,55,37,79,35,40,67,35,57,60,41,63,28,70,41,60,64,67,36,75,27,33,53,49,50,65,60,40,44,62,68,56,38,72,62,39,31,80,70,70,68,69,48,47,69,58,62,60,61,47,70,50,100,69,72,76,61,54,59,51,72,68,53,75,38,70,49,30,36,43,60,63,59,41,56,56],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003ePUNT_LECTURA_CRITIC ...

# %% [markdown]
# <font color=green size=4> Conclusiones: </font>
#
# ---
#
# El gráfico de dispersión se puede utilizar para relacionar datos entre dos variables numéricas de diferentes naturalezas. Esta relación puede ser positiva, negativa o neutra, lineal o no lineal.
#
# Aquí trazamos una línea en  torno a los datos que representa la tendencia entre ellos, similar al comportamiento que generamos al trabajar con modelos de regresión lineal.

# %% [markdown]
# ## **5.3 - Gráfico de dispersión con colores**
#
# ---

# %% [markdown]
# ### **Pregunta 2 -** ¿Cuál es la relación entre los puntajes de inglés y el puntaje global por departamento en la región norte de Colombia (Atlántico, Bolivar, Magdalena, Córdoba y Sucre) considerando a las familias que declararon atravesar una situación económica peor en el año 2020? ¿Podemos trazar algún paralelo entre ellas? Si se sabe que el puntaje para acceder automáticamente a una beca es igual o superior a 360 puntos, y si se considera que el nivel avanzado de inglés es B+ (superior a 80 puntos), ¿puedes mostrar este comportamiento con los 4000 primeros registros de este grupo de estudiantes?

# %% [markdown]
# #### Visualizando los datos

# %%
departamentos = ['ATLANTICO','BOLIVAR','MAGDALENA','CORDOBA','SUCRE']
saber_2020 = saber.query('FAMI_SITUACIONECONOMICA == "Peor" & PERIODO==2020 & DEPARTAMENTO in @departamentos')\
                        [['DEPARTAMENTO','PUNT_INGLES','PUNT_GLOBAL']]
saber_2020 = saber_2020.reset_index(drop=True)
saber_2020 = saber_2020.head(4000)
saber_2020
# Out:
#      DEPARTAMENTO  PUNT_INGLES  PUNT_GLOBAL
# 0         BOLIVAR         50.0          295
# 1       ATLANTICO         73.0          392
# 2       ATLANTICO         74.0          387
# 3         BOLIVAR         56.0          304
# 4       ATLANTICO         46.0          217
# ...           ...          ...          ...
# 3995      CORDOBA         40.0          242
# 3996    ATLANTICO         50.0          266
# 3997      CORDOBA         50.0          223
# 3998      CORDOBA         40.0          263
# 3999    MAGDALENA         51.0          240
#
# [4000 rows x 3 columns]

# %% [markdown]
# #### Generando el gráfico

# %%
colores=[VERDE3,ROJO2,AZUL3,NARANJA1,GRIS4]
fig,ax = plt.subplots(figsize=(10,5))
sns.set_theme(style='white')

ax = sns.scatterplot(data=saber_2020,x='PUNT_GLOBAL',y='PUNT_INGLES',
                     hue='DEPARTAMENTO',palette=colores)

plt.suptitle('Relación entre los puntajes de Inglés y Global de las pruebas Saber 11',
             size=18, color=GRIS1, ha = 'right', x = 0.97, y = 1.03)
plt.title('Familias que declaran situación económica peor (Año 2020 - Región Norte)',
          fontsize=14, color=GRIS3, pad = 15, loc = "left")
ax.legend(bbox_to_anchor=(305, 95), title='Departamento', title_fontsize  = 10,
          fontsize = 8, loc='upper left', bbox_transform=ax.transData)
ax.set_xlabel('Puntaje Global (0 - 500)', fontsize = 14)
ax.set_ylabel('Puntaje de Inglés (0 - 100)',  fontsize = 14)
ax.xaxis.set_tick_params(labelsize=12, color = GRIS2)
ax.set_xlim(300, 480)
ax.yaxis.set_tick_params(labelsize=12, color = GRIS2)
ax.set_ylim(70, 95)
sns.despine()

ax.text(ax.get_xlim()[0] + 1, 81, 'Nivel B+', fontsize=10, color = GRIS3, va = "bottom")
ax.text(ax.get_xlim()[0] + 1 , 79, 'Nivel B1', fontsize=10, color = GRIS3, va = "top")
plt.axhline(y = 80, color = GRIS5, linestyle='--')

ax.text(355, ax.get_ylim()[1] - 5, 'No clasifica\npara la beca', fontsize=10,
        color = GRIS3, ha="right")
ax.text(365, ax.get_ylim()[1] - 5, 'Sí clasifica\npara la beca', fontsize=10,
        color = GRIS3, ha="left")
plt.axvline(x = 360, color = GRIS5, linestyle='--')


ax.annotate("La línea vertical divide a los estudiantes\nque automáticamente clasifican para una beca (>=360 puntos).\n\n"
            "Se puede observar, para la muestra, que hay más estudiantes con nivel B1\n"
            "de inglés que acceden a la beca en comparación con los de nivel B+.",
            xy=(420, 74), xycoords='data',
            bbox=dict(boxstyle="round", fc=BLANCO, ec=GRIS3),
            xytext=(0, 0), textcoords='offset points')

plt.show()

# %% [markdown]
# <font color=green size=4> Conclusiones: </font>
#
# ---
#
# El gráfico de dispersión por colores añade una variable categórica al análisis (en nuestro ejemplo, la región).
#
# Para comprender un poco más sobre los niveles de proficiencia en el Saber 11, accede a este [link](https://eservicioseducativos.com/blog/interpretar-resultados-saber-11/).
#
# Aquí utilizamos dos recursos visuales: el de acercamiento (generado por la delimitación de los puntajes de inglés y global) y el de similitud a través de los colores, representando las categorías de los puntos representados por los departamentos en cuestión.
